# %%
pip install -q -U google-generativeai  # to run on local terminal run this first
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\veeranna\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\veeranna\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\veeranna\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\veeranna\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\veeranna\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\veeranna\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\veeranna\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\veeranna\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ordcloud (c:\users\veeranna\anaconda3\lib\site-packages)
# ...

# %%
import google.generativeai as genai
import os
# this line is used to acces the model
genai.configure(api_key="AIzaSyAo8DUEQwFUqoJRH_PG1WjxmfSyj-5WwG8")

#If you know the model name'
model=genai.GenerativeModel('gemini-1.5-pro')

# %%
# if you dont know the name of the model

for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# # Text-Model

# %%
model=genai.GenerativeModel('gemini-pro')
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
response= model.generate_content('List of top 5 indian cricketers')
print(response.text)
# Out:
# 1. Sachin Tendulkar
# 2. Virat Kohli
# 3. Kapil Dev
# 4. Sunil Gavaskar
# 5. MS Dhoni

# %% [markdown]
# - sometimes the text will be big

# %%
response= model.generate_content('is king jong un cruel guy?')
print(response.parts)
# Out:
# []

# %%
from google.generativeai.types import HarmCategory, HarmBlockThreshold

model = genai.GenerativeModel(model_name='gemini-pro')
response = model.generate_content(
    ('is king jong un cruel guy?'),
    safety_settings={
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
    }
)
print(response.parts)
# Out:
# [text: "King Jong-un is the Supreme Leader of North Korea. He is known for his authoritarian rule and his country\'s human rights abuses. He has been accused of ordering the assassination of his uncle, Jang Song-thaek; imprisoning and torturing political dissidents; and carrying out public executions. He has also been criticized for his nuclear and missile programs, which have raised concerns about the stability of the Korean Peninsula.\n\nThere is no consensus on whether King Jong-un is a cruel person. Some people believe that he is a ruthless dictator who has no regard for human life. Others believe that he is a product of his environment and that his actions are driven by the need to maintain control over his country.\n\nUltimately, it is up to each individual to decide whether or not they believe that King Jong-un is a cruel person. There is no right or wrong answer, and there is no one definitive way to measure cruelty."
# ]

# %% [markdown]
# # Image model

# %%
from PIL import Image
img=Image.open('/content/sheepgenai.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
import google.generativeai as genai
import os
# this line is used to acces the model
genai.configure(api_key="AIzaSyAo8DUEQwFUqoJRH_PG1WjxmfSyj-5WwG8")

#If you know the model name'
model=genai.GenerativeModel('gemini-1.0-pro-vision-latest')
prompt="Generate a movie tittle based on above image"


response=model.generate_content([prompt,img])
print("Movie Tittle:",response.text)
img
# Out:
# Movie Tittle:  The shearer
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>
